# %%
import json

# %%
with open("authors1000.json", "r") as read_file:
    dataAuthors = json.load(read_file)

# %%
resultsAuthors = list(filter(lambda x: x['name'] == 'Stephen King', data))
resultsAuthors
# Out:
# [{'authorid': 3389,
#   'name': 'Stephen King',
#   'workcount': 1653,
#   'fan_count': 709826,
#   'gender': 'male',
#   'image_url': 'https://images.gr-assets.com/authors/1362814142p7/3389.jpg',
# ...

# %%
with open("librosJ.json", "r") as read_file:
    dataBooks = json.load(read_file)
resultsBooks = list(filter(lambda x: 'Stephen King' in x['authors'], dataBooks))
resultsBooks
# Out:
# bn': 453007449,
#   'isbn13': 9780453007440,
#   'authors': 'Stephen King, Willem Dafoe',
#   'original_publication_year': 1989,
#   'original_title': 'Four Past Midnight',
#   'title': 'One Past Midnight: The Langoliers',
#   'language_code': 'eng',
#   'average_rating': 3.82,
#   'ratings_count': 22326,
#   'work_ratings_count': 26431,
#   'work_text_reviews_count': 360,
#   'ratings_1': 415,
#   'ratings_2': 1823,
#   'ratings_3': 7507,
#   'ratings_4': 9151,
#   'ratings_5': 7535,
#   'image_url': 'https://images.gr-assets.com/books/1429051428m/102733.jpg',
#   'small_image_url': 'https://images.gr-assets.com/books/1429051428s/102733.jpg'},
#  {'id': 4642,
#   'book_id': 11574,
#   'best_book_id': 11574,
#   'work_id': 2334601,
#   'books_count': 37,
#   'isbn': 582418178,
#   'isbn13': 9780582418170,
#   'authors': 'Stephen King, Robin A.H. Waterfield',
#   'original_publication_year': 1982,
#   'original_title': 'Different Seasons',
#   'title': 'The Body',
# ...

# %%
from model_view_controller import ModelBasic
# Out:
# Empezo el constructor Autor
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-4bd5de79cf3a> in <module>
# ----> 1 from model_view_controller import ModelBasic
#
# ~/Documents/7moSemestre/Python/py-aguilar-quezada-henry-gonzalo/Deberes/Deber 01/model_view_controller.py in <module>
#     194
#     195
# --> 196 c = Controller(ModelBasic(my_items), View())
#     197 c.show_items()
#     198 c.show_items(bullet_points=True)
#
# ~/Documents/7moSemestre/Python/py-aguilar-quezada-henry-gonzalo/Deberes/Deber 01/model_view_controller.py in __init__(self, application_items)
#      10     def __init__(self, application_items):
#      11         self._item_type = 'author'
# ---> 12         self.create_items(application_items)
#      13
#      14     @property
#
# ...

# %%
nuevoAutor = [{
            'authorid' : input("ingresa author id: "),
            'name' : input("ingresa author name: ")
        }]
print(nuevoAutor)
